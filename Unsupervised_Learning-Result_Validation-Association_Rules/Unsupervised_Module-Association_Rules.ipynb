# %% [markdown]
# # Módulo de Aprendizaje No-Supervisado (Ejercicios Prácticos)
#
# > Ejemplos generales de Reglas de Asociación en Python

# %% [markdown]
# **Apriori** (Reglas de Asociación extraídas con paquete apyori)

# %%
# !pip install apyori

#importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
#importing the weather dataset 

weather = pd.read_csv("/content/weather.nominal.csv")
num_records = len(weather)
num_columns = len(weather.columns)

print("Cantidad de instancias: ", num_records)
print("Cantidad de columnas: ", num_columns)
print(weather)

# %%
#modifying the weather dataset
 
records=[]
for i in range(0, num_records):
  records.append([weather.columns[j]+"="+str(weather.values[i,j]) for j in range(0, num_columns)])
print(records)

# %%
#association rules extraction

my_association_rules = apriori(records, min_support=0.0045, min_confidence=1, min_lift=1.5, min_length=2)
association_results = list(my_association_rules) #best format to show rules
print(association_results)

# %%
#print association rules 

rule_number = 0
for item in association_results:

    items_base  = item[2][0][0]
    antecedente = [x for x in items_base]

    items_add   = item[2][0][1]
    concecuente = [x for x in items_add]
 
    rule_number += 1
    print("Rule #",rule_number,":  ",antecedente," --> ",concecuente)
    print("Support: " + str(item[1]))
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")

# %% [markdown]
# **FP-Growth** (Reglas de Asociación extraídas con librería mlxtend)

# %%
#Se debe re-instalar la versión actual de mlxtend (incompleta la que provee google)
#Se debe reiniciar el entorno de ejecución y ejecutar todas las celdas anteriores para recuperar variables necesarias

# !pip uninstall mlxtend -y
# !pip install mlxtend

# %%
#importing the libraries

from mlxtend.preprocessing     import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df = pd.DataFrame(te_ary, columns=te.columns_)
df

#Extract frecuent itemsets

frequent_itemsets = fpgrowth(df, min_support=0.2, use_colnames=True)
#frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)  #También es posible utilizar el algoritmo Apriori

# %%
#Extract association rules from frecuent itemsets

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
rules
# Out:
#                             antecedents                  consequents  \
# 0                         (windy=False)                   (play=yes)
# 1                             (play=no)              (humidity=high)
# 2        (outlook=sunny, humidity=high)                    (play=no)
# 3              (outlook=sunny, play=no)              (humidity=high)
# 4              (humidity=high, play=no)              (outlook=sunny)
# 5                     (temperature=hot)              (humidity=high)
# 6                     (temperature=hot)                (windy=False)
# 7                    (outlook=overcast)                   (play=yes)
# 8             (play=yes, outlook=rainy)                (windy=False)
# 9          (outlook=rainy, windy=False)                   (play=yes)
# 10                    (humidity=normal)                   (play=yes)
# 11       (humidity=normal, windy=False)                   (play=yes)
# 12                   (temperature=cool)            (humidity=normal)
# 13                   (temperature=cool)                   (play=yes)
# 14  (temperature=cool, humidity=normal)                   (play=yes)
# 15         (temperature=cool, play=yes)            (humidity=normal)
# 16                   (temperature=cool)  (humidity=normal, play=yes)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.571429            0.642857  0.428571    0.750000  1.166667
# 1             0.357143            0.500000  0.285714    0.800000  1.600000
# 2             0.214286            0.357143  0.214286    1.000000  2.800000
# 3             0.214286            0.500000  0.214286    1.000000  2.000000
# 4             0.285714            0.357143  0.214286    0.750000  2.100000
# 5             0.285714            0.500000  0.214286    0.750000  1.500000
# 6             0.285714            0.571429  0.214286    0.750000  1.312500
# 7             0.285714            0.642857  0.285714    1.000000  1.555556
# 8             0.214286            0.571429  0.214286    1.000000  1.750000
# 9             0.214286            0.642857  0.214286    1.000000  1.555556
# 10            0.500000            0.642857  0.428571    0.857143  1.333333
# 11            0.285714            0.642857  0.285714    1.000000  1.555556
# 12            0.285714            0.500000  0.285714    1.000000  2.000000
# 13            0.285714            0.642857  0.214286    0.750000  1.166667
# 14            0.285714            0.642857  0.214286    0.750000  1.166667
# 15            0.214286            0.500000  0.214286    1.000000  2.000000
# 16            0.285714            0.428571  0.214286    0.750000  1.750000
#
#     leverage  conviction
# 0   0.061224    1.428571
# 1   0.107143    2.500000
# 2   0.137755         inf
# 3   0.107143         inf
# 4   0.112245    2.571429
# 5   0.071429    2.000000
# 6   0.051020    1.714286
# 7   0.102041         inf
# 8   0.091837         inf
# 9   0.076531         inf
# 10  0.107143    2.500000
# 11  0.102041         inf
# 12  0.142857         inf
# 13  0.030612    1.428571
# 14  0.030612    1.428571
# 15  0.107143         inf
# 16  0.091837    2.285714

# %%
#Filtrar las reglas con otras métricas

rules[ (rules['confidence'] > 0.75) &
       (rules['lift'] > 1.2) ]
# Out:
#                        antecedents        consequents  antecedent support  \
# 1                        (play=no)    (humidity=high)            0.357143
# 2   (outlook=sunny, humidity=high)          (play=no)            0.214286
# 3         (outlook=sunny, play=no)    (humidity=high)            0.214286
# 7               (outlook=overcast)         (play=yes)            0.285714
# 8        (play=yes, outlook=rainy)      (windy=False)            0.214286
# 9     (outlook=rainy, windy=False)         (play=yes)            0.214286
# 10               (humidity=normal)         (play=yes)            0.500000
# 11  (humidity=normal, windy=False)         (play=yes)            0.285714
# 12              (temperature=cool)  (humidity=normal)            0.285714
# 15    (temperature=cool, play=yes)  (humidity=normal)            0.214286
#
#     consequent support   support  confidence      lift  leverage  conviction
# 1             0.500000  0.285714    0.800000  1.600000  0.107143         2.5
# 2             0.357143  0.214286    1.000000  2.800000  0.137755         inf
# 3             0.500000  0.214286    1.000000  2.000000  0.107143         inf
# 7             0.642857  0.285714    1.000000  1.555556  0.102041         inf
# 8             0.571429  0.214286    1.000000  1.750000  0.091837         inf
# 9             0.642857  0.214286    1.000000  1.555556  0.076531         inf
# 10            0.642857  0.428571    0.857143  1.333333  0.107143         2.5
# 11            0.642857  0.285714    1.000000  1.555556  0.102041         inf
# 12            0.500000  0.285714    1.000000  2.000000  0.142857         inf
# 15            0.500000  0.214286    1.000000  2.000000  0.107143         inf

# %%
#Filtrar las reglas con antecedentes o consecuentes

rules[ (rules['consequents'] == {'play=no'}) | 
       (rules['consequents'] == {'play=yes'})]
# Out:
#                             antecedents consequents  antecedent support  \
# 0                         (windy=False)  (play=yes)            0.571429
# 2        (outlook=sunny, humidity=high)   (play=no)            0.214286
# 7                    (outlook=overcast)  (play=yes)            0.285714
# 9          (outlook=rainy, windy=False)  (play=yes)            0.214286
# 10                    (humidity=normal)  (play=yes)            0.500000
# 11       (humidity=normal, windy=False)  (play=yes)            0.285714
# 13                   (temperature=cool)  (play=yes)            0.285714
# 14  (temperature=cool, humidity=normal)  (play=yes)            0.285714
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.642857  0.428571    0.750000  1.166667  0.061224    1.428571
# 2             0.357143  0.214286    1.000000  2.800000  0.137755         inf
# 7             0.642857  0.285714    1.000000  1.555556  0.102041         inf
# 9             0.642857  0.214286    1.000000  1.555556  0.076531         inf
# 10            0.642857  0.428571    0.857143  1.333333  0.107143    2.500000
# 11            0.642857  0.285714    1.000000  1.555556  0.102041         inf
# 13            0.642857  0.214286    0.750000  1.166667  0.030612    1.428571
# 14            0.642857  0.214286    0.750000  1.166667  0.030612    1.428571

# %%
rules.sort_values('confidence',ascending = False,inplace=True)
rules.head(20)
# Out:
#                             antecedents                  consequents  \
# 8             (play=yes, outlook=rainy)                (windy=False)
# 12                   (temperature=cool)            (humidity=normal)
# 2        (outlook=sunny, humidity=high)                    (play=no)
# 3              (outlook=sunny, play=no)              (humidity=high)
# 15         (temperature=cool, play=yes)            (humidity=normal)
# 7                    (outlook=overcast)                   (play=yes)
# 9          (outlook=rainy, windy=False)                   (play=yes)
# 11       (humidity=normal, windy=False)                   (play=yes)
# 10                    (humidity=normal)                   (play=yes)
# 1                             (play=no)              (humidity=high)
# 14  (temperature=cool, humidity=normal)                   (play=yes)
# 13                   (temperature=cool)                   (play=yes)
# 0                         (windy=False)                   (play=yes)
# 6                     (temperature=hot)                (windy=False)
# 5                     (temperature=hot)              (humidity=high)
# 4              (humidity=high, play=no)              (outlook=sunny)
# 16                   (temperature=cool)  (humidity=normal, play=yes)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 8             0.214286            0.571429  0.214286    1.000000  1.750000
# 12            0.285714            0.500000  0.285714    1.000000  2.000000
# 2             0.214286            0.357143  0.214286    1.000000  2.800000
# 3             0.214286            0.500000  0.214286    1.000000  2.000000
# 15            0.214286            0.500000  0.214286    1.000000  2.000000
# 7             0.285714            0.642857  0.285714    1.000000  1.555556
# 9             0.214286            0.642857  0.214286    1.000000  1.555556
# 11            0.285714            0.642857  0.285714    1.000000  1.555556
# 10            0.500000            0.642857  0.428571    0.857143  1.333333
# 1             0.357143            0.500000  0.285714    0.800000  1.600000
# 14            0.285714            0.642857  0.214286    0.750000  1.166667
# 13            0.285714            0.642857  0.214286    0.750000  1.166667
# 0             0.571429            0.642857  0.428571    0.750000  1.166667
# 6             0.285714            0.571429  0.214286    0.750000  1.312500
# 5             0.285714            0.500000  0.214286    0.750000  1.500000
# 4             0.285714            0.357143  0.214286    0.750000  2.100000
# 16            0.285714            0.428571  0.214286    0.750000  1.750000
#
#     leverage  conviction
# 8   0.091837         inf
# 12  0.142857         inf
# 2   0.137755         inf
# 3   0.107143         inf
# 15  0.107143         inf
# 7   0.102041         inf
# 9   0.076531         inf
# 11  0.102041         inf
# 10  0.107143    2.500000
# 1   0.107143    2.500000
# 14  0.030612    1.428571
# 13  0.030612    1.428571
# 0   0.061224    1.428571
# 6   0.051020    1.714286
# 5   0.071429    2.000000
# 4   0.112245    2.571429
# 16  0.091837    2.285714
